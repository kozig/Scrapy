# %%
import requests
import time
import os

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

from bs4 import BeautifulSoup

import pandas as pd

# %%
# Create Chrome options
chrome_options = webdriver.ChromeOptions()
# chrome_options.add_argument("--headless")
driver = webdriver.Chrome(options=chrome_options)

# Province list to iterate through to make it less resource intense.
prov_list = {1: "ON", 2: "BC", 3: "MB",
             4: "AB", 5: "NB", 6: "NL",
             7: "NT", 8: "NS", 9: "NU", 
             10: "PE", 11: "QC", 12: "SK", 
             13: "YT"
            }
prov_scraped = []
data_list = []
# For testing.
# prov = prov_list[7]

# %%
for p in prov_list:
    prov = prov_list[p]
    print(prov)
    prov_scraped.append(prov)
    driver.get(f"https://www.jobbank.gc.ca/jobsearch/jobsearch?sort=M&fprov={prov}")
    wait = WebDriverWait(driver, 2)
    click_count = 0
    button_present = driver.find_element(By.ID, 'moreresultbutton').is_displayed()
    print(button_present)  
    
    # Click the "more results", button to load all the listings to the page.
    while button_present:
        try:
            print('Click attempt')
            button = wait.until(EC.element_to_be_clickable((By.ID, "moreresultbutton")))
            button.click()
            time.sleep(2)
            click_count += 1
            print(f'clicked: {click_count} times.')
            button_present = driver.find_element(By.ID, 'moreresultbutton').is_displayed()
        except:
            print("All done!")
            break
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    main_box = soup.findAll("article") # Find all the job listings on the page.
    
    # Iterate through all job listings.
    for box in main_box:
        temp_dict = {} # Dict of job posting.
        temp_dict['job_title'] = box.find("span", {"class": "noctitle"}).text.replace('\n', '').replace('\t', '').strip()
        temp_dict['business'] =  box.find("li", {"class": "business"}).text
        temp_dict['location'] =  box.find("li", {"class": "location"}).text.replace('\n', '').replace('\t', '').replace('Location', '').strip()
        temp_dict['salary'] =    box.find("li", {"class": "salary"}).text.replace('\n', '').replace('\t', '').strip()
        temp_dict['link'] =      box.find("a", {"class": "resultJobItem"})["href"]
        temp_dict['date'] =      box.find("li", {"class": "date"}).text.replace('\n', '').replace('\t', '').strip()
        
        data_list.append(temp_dict)
# Out:
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# clicked: 6 times.
# Click attempt
# clicked: 7 times.
# Click attempt
# clicked: 8 times.
# Click attempt
# clicked: 9 times.
# Click attempt
# clicked: 10 times.
# Click attempt
# clicked: 11 times.
# Click attempt
# clicked: 12 times.
# Click attempt
# clicked: 13 times.
# Click attempt
# clicked: 14 times.
# Click attempt
# clicked: 15 times.
# Click attempt
# clicked: 16 times.
# Click attempt
# clicked: 17 times.
# Click attempt
# clicked: 18 times.
# Click attempt
# clicked: 19 times.
# Click attempt
# clicked: 20 times.
# Click attempt
# clicked: 21 times.
# Click attempt
# clicked: 22 times.
# Click attempt
# clicked: 23 times.
# Click attempt
# clicked: 24 times.
# Click attempt
# clicked: 25 times.
# Click attempt
# clicked: 26 times.
# Click attempt
# clicked: 27 times.
# Click attempt
# clicked: 28 times.
# Click attempt
# clicked: 29 times.
# Click attempt
# clicked: 30 times.
# Click attempt
# clicked: 31 times.
# Click attempt
# clicked: 32 times.
# Click attempt
# clicked: 33 times.
# Click attempt
# clicked: 34 times.
# Click attempt
# clicked: 35 times.
# Click attempt
# clicked: 36 times.
# Click attempt
# clicked: 37 times.
# Click attempt
# clicked: 38 times.
# Click attempt
# clicked: 39 times.
# Click attempt
# clicked: 40 times.
# Click attempt
# clicked: 41 times.
# Click attempt
# clicked: 42 times.
# Click attempt
# clicked: 43 times.
# Click attempt
# clicked: 44 times.
# Click attempt
# clicked: 45 times.
# Click attempt
# clicked: 46 times.
# Click attempt
# clicked: 47 times.
# Click attempt
# clicked: 48 times.
# Click attempt
# clicked: 49 times.
# Click attempt
# clicked: 50 times.
# Click attempt
# clicked: 51 times.
# Click attempt
# clicked: 52 times.
# Click attempt
# clicked: 53 times.
# Click attempt
# clicked: 54 times.
# Click attempt
# clicked: 55 times.
# Click attempt
# clicked: 56 times.
# Click attempt
# clicked: 57 times.
# Click attempt
# clicked: 58 times.
# Click attempt
# clicked: 59 times.
# Click attempt
# clicked: 60 times.
# Click attempt
# clicked: 61 times.
# Click attempt
# clicked: 62 times.
# Click attempt
# clicked: 63 times.
# Click attempt
# clicked: 64 times.
# Click attempt
# clicked: 65 times.
# Click attempt
# clicked: 66 times.
# Click attempt
# clicked: 67 times.
# Click attempt
# clicked: 68 times.
# Click attempt
# clicked: 69 times.
# Click attempt
# clicked: 70 times.
# Click attempt
# clicked: 71 times.
# Click attempt
# clicked: 72 times.
# Click attempt
# clicked: 73 times.
# Click attempt
# clicked: 74 times.
# Click attempt
# clicked: 75 times.
# Click attempt
# clicked: 76 times.
# Click attempt
# clicked: 77 times.
# Click attempt
# clicked: 78 times.
# Click attempt
# clicked: 79 times.
# Click attempt
# clicked: 80 times.
# Click attempt
# clicked: 81 times.
# Click attempt
# clicked: 82 times.
# Click attempt
# clicked: 83 times.
# Click attempt
# clicked: 84 times.
# Click attempt
# clicked: 85 times.
# Click attempt
# clicked: 86 times.
# Click attempt
# clicked: 87 times.
# Click attempt
# clicked: 88 times.
# Click attempt
# clicked: 89 times.
# Click attempt
# clicked: 90 times.
# Click attempt
# clicked: 91 times.
# Click attempt
# clicked: 92 times.
# Click attempt
# clicked: 93 times.
# Click attempt
# clicked: 94 times.
# Click attempt
# clicked: 95 times.
# Click attempt
# clicked: 96 times.
# Click attempt
# clicked: 97 times.
# Click attempt
# clicked: 98 times.
# Click attempt
# clicked: 99 times.
# Click attempt
# clicked: 100 times.
# Click attempt
# clicked: 101 times.
# Click attempt
# clicked: 102 times.
# Click attempt
# clicked: 103 times.
# Click attempt
# clicked: 104 times.
# Click attempt
# clicked: 105 times.
# Click attempt
# clicked: 106 times.
# Click attempt
# clicked: 107 times.
# Click attempt
# clicked: 108 times.
# Click attempt
# clicked: 109 times.
# Click attempt
# clicked: 110 times.
# Click attempt
# clicked: 111 times.
# Click attempt
# clicked: 112 times.
# Click attempt
# clicked: 113 times.
# Click attempt
# clicked: 114 times.
# Click attempt
# clicked: 115 times.
# Click attempt
# clicked: 116 times.
# Click attempt
# clicked: 117 times.
# Click attempt
# clicked: 118 times.
# Click attempt
# clicked: 119 times.
# Click attempt
# clicked: 120 times.
# Click attempt
# clicked: 121 times.
# Click attempt
# clicked: 122 times.
# Click attempt
# clicked: 123 times.
# Click attempt
# clicked: 124 times.
# Click attempt
# clicked: 125 times.
# Click attempt
# clicked: 126 times.
# Click attempt
# clicked: 127 times.
# Click attempt
# clicked: 128 times.
# Click attempt
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# clicked: 6 times.
# Click attempt
# clicked: 7 times.
# Click attempt
# clicked: 8 times.
# Click attempt
# clicked: 9 times.
# Click attempt
# clicked: 10 times.
# Click attempt
# clicked: 11 times.
# Click attempt
# clicked: 12 times.
# Click attempt
# clicked: 13 times.
# Click attempt
# clicked: 14 times.
# Click attempt
# clicked: 15 times.
# Click attempt
# clicked: 16 times.
# Click attempt
# clicked: 17 times.
# Click attempt
# clicked: 18 times.
# Click attempt
# clicked: 19 times.
# Click attempt
# clicked: 20 times.
# Click attempt
# clicked: 21 times.
# Click attempt
# clicked: 22 times.
# Click attempt
# clicked: 23 times.
# Click attempt
# clicked: 24 times.
# Click attempt
# clicked: 25 times.
# Click attempt
# clicked: 26 times.
# Click attempt
# clicked: 27 times.
# Click attempt
# clicked: 28 times.
# Click attempt
# clicked: 29 times.
# Click attempt
# clicked: 30 times.
# Click attempt
# clicked: 31 times.
# Click attempt
# clicked: 32 times.
# Click attempt
# clicked: 33 times.
# Click attempt
# clicked: 34 times.
# Click attempt
# clicked: 35 times.
# Click attempt
# clicked: 36 times.
# Click attempt
# clicked: 37 times.
# Click attempt
# clicked: 38 times.
# Click attempt
# clicked: 39 times.
# Click attempt
# clicked: 40 times.
# Click attempt
# clicked: 41 times.
# Click attempt
# clicked: 42 times.
# Click attempt
# clicked: 43 times.
# Click attempt
# clicked: 44 times.
# Click attempt
# clicked: 45 times.
# Click attempt
# clicked: 46 times.
# Click attempt
# clicked: 47 times.
# Click attempt
# clicked: 48 times.
# Click attempt
# clicked: 49 times.
# Click attempt
# clicked: 50 times.
# Click attempt
# clicked: 51 times.
# Click attempt
# clicked: 52 times.
# Click attempt
# clicked: 53 times.
# Click attempt
# clicked: 54 times.
# Click attempt
# clicked: 55 times.
# Click attempt
# clicked: 56 times.
# Click attempt
# clicked: 57 times.
# Click attempt
# clicked: 58 times.
# Click attempt
# clicked: 59 times.
# Click attempt
# clicked: 60 times.
# Click attempt
# clicked: 61 times.
# Click attempt
# clicked: 62 times.
# Click attempt
# clicked: 63 times.
# Click attempt
# clicked: 64 times.
# Click attempt
# clicked: 65 times.
# Click attempt
# clicked: 66 times.
# Click attempt
# clicked: 67 times.
# Click attempt
# clicked: 68 times.
# Click attempt
# clicked: 69 times.
# Click attempt
# clicked: 70 times.
# Click attempt
# clicked: 71 times.
# Click attempt
# clicked: 72 times.
# Click attempt
# clicked: 73 times.
# Click attempt
# clicked: 74 times.
# Click attempt
# clicked: 75 times.
# Click attempt
# clicked: 76 times.
# Click attempt
# clicked: 77 times.
# Click attempt
# clicked: 78 times.
# Click attempt
# clicked: 79 times.
# Click attempt
# clicked: 80 times.
# Click attempt
# clicked: 81 times.
# Click attempt
# clicked: 82 times.
# Click attempt
# clicked: 83 times.
# Click attempt
# clicked: 84 times.
# Click attempt
# clicked: 85 times.
# Click attempt
# clicked: 86 times.
# Click attempt
# clicked: 87 times.
# Click attempt
# clicked: 88 times.
# Click attempt
# clicked: 89 times.
# Click attempt
# clicked: 90 times.
# Click attempt
# clicked: 91 times.
# Click attempt
# clicked: 92 times.
# Click attempt
# clicked: 93 times.
# Click attempt
# clicked: 94 times.
# Click attempt
# clicked: 95 times.
# Click attempt
# clicked: 96 times.
# Click attempt
# clicked: 97 times.
# Click attempt
# clicked: 98 times.
# Click attempt
# clicked: 99 times.
# Click attempt
# clicked: 100 times.
# Click attempt
# clicked: 101 times.
# Click attempt
# clicked: 102 times.
# Click attempt
# clicked: 103 times.
# Click attempt
# clicked: 104 times.
# Click attempt
# clicked: 105 times.
# Click attempt
# clicked: 106 times.
# Click attempt
# clicked: 107 times.
# Click attempt
# clicked: 108 times.
# Click attempt
# clicked: 109 times.
# Click attempt
# clicked: 110 times.
# Click attempt
# clicked: 111 times.
# Click attempt
# clicked: 112 times.
# Click attempt
# clicked: 113 times.
# Click attempt
# clicked: 114 times.
# Click attempt
# clicked: 115 times.
# Click attempt
# clicked: 116 times.
# Click attempt
# clicked: 117 times.
# Click attempt
# clicked: 118 times.
# Click attempt
# clicked: 119 times.
# Click attempt
# clicked: 120 times.
# Click attempt
# clicked: 121 times.
# Click attempt
# clicked: 122 times.
# Click attempt
# clicked: 123 times.
# Click attempt
# clicked: 124 times.
# Click attempt
# clicked: 125 times.
# Click attempt
# clicked: 126 times.
# Click attempt
# clicked: 127 times.
# Click attempt
# clicked: 128 times.
# Click attempt
# clicked: 129 times.
# Click attempt
# clicked: 130 times.
# Click attempt
# clicked: 131 times.
# Click attempt
# clicked: 132 times.
# Click attempt
# clicked: 133 times.
# Click attempt
# clicked: 134 times.
# Click attempt
# clicked: 135 times.
# Click attempt
# clicked: 136 times.
# Click attempt
# clicked: 137 times.
# Click attempt
# clicked: 138 times.
# Click attempt
# clicked: 139 times.
# Click attempt
# clicked: 140 times.
# Click attempt
# clicked: 141 times.
# Click attempt
# clicked: 142 times.
# Click attempt
# clicked: 143 times.
# Click attempt
# clicked: 144 times.
# Click attempt
# clicked: 145 times.
# Click attempt
# clicked: 146 times.
# Click attempt
# clicked: 147 times.
# Click attempt
# clicked: 148 times.
# Click attempt
# clicked: 149 times.
# Click attempt
# clicked: 150 times.
# Click attempt
# clicked: 151 times.
# Click attempt
# clicked: 152 times.
# Click attempt
# clicked: 153 times.
# Click attempt
# clicked: 154 times.
# Click attempt
# clicked: 155 times.
# Click attempt
# clicked: 156 times.
# Click attempt
# clicked: 157 times.
# Click attempt
# clicked: 158 times.
# Click attempt
# clicked: 159 times.
# Click attempt
# clicked: 160 times.
# Click attempt
# clicked: 161 times.
# Click attempt
# clicked: 162 times.
# Click attempt
# clicked: 163 times.
# Click attempt
# clicked: 164 times.
# Click attempt
# clicked: 165 times.
# Click attempt
# clicked: 166 times.
# Click attempt
# clicked: 167 times.
# Click attempt
# clicked: 168 times.
# Click attempt
# clicked: 169 times.
# Click attempt
# clicked: 170 times.
# Click attempt
# clicked: 171 times.
# Click attempt
# clicked: 172 times.
# Click attempt
# clicked: 173 times.
# Click attempt
# clicked: 174 times.
# Click attempt
# clicked: 175 times.
# Click attempt
# clicked: 176 times.
# Click attempt
# clicked: 177 times.
# Click attempt
# clicked: 178 times.
# Click attempt
# clicked: 179 times.
# Click attempt
# clicked: 180 times.
# Click attempt
# clicked: 181 times.
# Click attempt
# clicked: 182 times.
# Click attempt
# clicked: 183 times.
# Click attempt
# clicked: 184 times.
# Click attempt
# clicked: 185 times.
# Click attempt
# clicked: 186 times.
# Click attempt
# clicked: 187 times.
# Click attempt
# clicked: 188 times.
# Click attempt
# clicked: 189 times.
# Click attempt
# clicked: 190 times.
# Click attempt
# clicked: 191 times.
# Click attempt
# clicked: 192 times.
# Click attempt
# clicked: 193 times.
# Click attempt
# clicked: 194 times.
# Click attempt
# clicked: 195 times.
# Click attempt
# clicked: 196 times.
# Click attempt
# clicked: 197 times.
# Click attempt
# clicked: 198 times.
# Click attempt
# clicked: 199 times.
# Click attempt
# clicked: 200 times.
# Click attempt
# clicked: 201 times.
# Click attempt
# clicked: 202 times.
# Click attempt
# clicked: 203 times.
# Click attempt
# clicked: 204 times.
# Click attempt
# clicked: 205 times.
# Click attempt
# clicked: 206 times.
# Click attempt
# clicked: 207 times.
# Click attempt
# clicked: 208 times.
# Click attempt
# clicked: 209 times.
# Click attempt
# clicked: 210 times.
# Click attempt
# clicked: 211 times.
# Click attempt
# clicked: 212 times.
# Click attempt
# clicked: 213 times.
# Click attempt
# clicked: 214 times.
# Click attempt
# clicked: 215 times.
# Click attempt
# clicked: 216 times.
# Click attempt
# clicked: 217 times.
# Click attempt
# clicked: 218 times.
# Click attempt
# clicked: 219 times.
# Click attempt
# clicked: 220 times.
# Click attempt
# clicked: 221 times.
# Click attempt
# clicked: 222 times.
# Click attempt
# clicked: 223 times.
# Click attempt
# clicked: 224 times.
# Click attempt
# clicked: 225 times.
# Click attempt
# clicked: 226 times.
# Click attempt
# clicked: 227 times.
# Click attempt
# clicked: 228 times.
# Click attempt
# clicked: 229 times.
# Click attempt
# clicked: 230 times.
# Click attempt
# clicked: 231 times.
# Click attempt
# clicked: 232 times.
# Click attempt
# clicked: 233 times.
# Click attempt
# clicked: 234 times.
# Click attempt
# clicked: 235 times.
# Click attempt
# clicked: 236 times.
# Click attempt
# clicked: 237 times.
# Click attempt
# clicked: 238 times.
# Click attempt
# clicked: 239 times.
# Click attempt
# clicked: 240 times.
# Click attempt
# clicked: 241 times.
# Click attempt
# clicked: 242 times.
# Click attempt
# clicked: 243 times.
# Click attempt
# clicked: 244 times.
# Click attempt
# clicked: 245 times.
# Click attempt
# clicked: 246 times.
# Click attempt
# clicked: 247 times.
# Click attempt
# clicked: 248 times.
# Click attempt
# clicked: 249 times.
# Click attempt
# clicked: 250 times.
# Click attempt
# clicked: 251 times.
# Click attempt
# clicked: 252 times.
# Click attempt
# clicked: 253 times.
# Click attempt
# clicked: 254 times.
# Click attempt
# clicked: 255 times.
# Click attempt
# clicked: 256 times.
# Click attempt
# clicked: 257 times.
# Click attempt
# clicked: 258 times.
# Click attempt
# clicked: 259 times.
# Click attempt
# clicked: 260 times.
# Click attempt
# clicked: 261 times.
# Click attempt
# clicked: 262 times.
# Click attempt
# clicked: 263 times.
# Click attempt
# clicked: 264 times.
# Click attempt
# clicked: 265 times.
# Click attempt
# clicked: 266 times.
# Click attempt
# clicked: 267 times.
# Click attempt
# clicked: 268 times.
# Click attempt
# clicked: 269 times.
# Click attempt
# clicked: 270 times.
# Click attempt
# clicked: 271 times.
# Click attempt
# clicked: 272 times.
# Click attempt
# clicked: 273 times.
# Click attempt
# clicked: 274 times.
# Click attempt
# clicked: 275 times.
# Click attempt
# clicked: 276 times.
# Click attempt
# clicked: 277 times.
# Click attempt
# clicked: 278 times.
# Click attempt
# clicked: 279 times.
# Click attempt
# clicked: 280 times.
# Click attempt
# clicked: 281 times.
# Click attempt
# clicked: 282 times.
# Click attempt
# clicked: 283 times.
# Click attempt
# clicked: 284 times.
# Click attempt
# clicked: 285 times.
# Click attempt
# clicked: 286 times.
# Click attempt
# clicked: 287 times.
# Click attempt
# clicked: 288 times.
# Click attempt
# clicked: 289 times.
# Click attempt
# clicked: 290 times.
# Click attempt
# clicked: 291 times.
# Click attempt
# clicked: 292 times.
# Click attempt
# clicked: 293 times.
# Click attempt
# clicked: 294 times.
# Click attempt
# clicked: 295 times.
# Click attempt
# clicked: 296 times.
# Click attempt
# clicked: 297 times.
# Click attempt
# clicked: 298 times.
# Click attempt
# clicked: 299 times.
# Click attempt
# clicked: 300 times.
# Click attempt
# clicked: 301 times.
# Click attempt
# clicked: 302 times.
# Click attempt
# clicked: 303 times.
# Click attempt
# clicked: 304 times.
# Click attempt
# clicked: 305 times.
# Click attempt
# clicked: 306 times.
# Click attempt
# clicked: 307 times.
# Click attempt
# clicked: 308 times.
# Click attempt
# clicked: 309 times.
# Click attempt
# clicked: 310 times.
# Click attempt
# clicked: 311 times.
# Click attempt
# clicked: 312 times.
# Click attempt
# clicked: 313 times.
# Click attempt
# clicked: 314 times.
# Click attempt
# clicked: 315 times.
# Click attempt
# clicked: 316 times.
# Click attempt
# clicked: 317 times.
# Click attempt
# clicked: 318 times.
# Click attempt
# clicked: 319 times.
# Click attempt
# clicked: 320 times.
# Click attempt
# clicked: 321 times.
# Click attempt
# clicked: 322 times.
# Click attempt
# clicked: 323 times.
# Click attempt
# clicked: 324 times.
# Click attempt
# clicked: 325 times.
# Click attempt
# clicked: 326 times.
# Click attempt
# clicked: 327 times.
# Click attempt
# clicked: 328 times.
# Click attempt
# clicked: 329 times.
# Click attempt
# clicked: 330 times.
# Click attempt
# clicked: 331 times.
# Click attempt
# clicked: 332 times.
# Click attempt
# clicked: 333 times.
# Click attempt
# clicked: 334 times.
# Click attempt
# clicked: 335 times.
# Click attempt
# clicked: 336 times.
# Click attempt
# clicked: 337 times.
# Click attempt
# clicked: 338 times.
# Click attempt
# clicked: 339 times.
# Click attempt
# clicked: 340 times.
# Click attempt
# clicked: 341 times.
# Click attempt
# clicked: 342 times.
# Click attempt
# clicked: 343 times.
# Click attempt
# clicked: 344 times.
# Click attempt
# clicked: 345 times.
# Click attempt
# clicked: 346 times.
# Click attempt
# clicked: 347 times.
# Click attempt
# clicked: 348 times.
# Click attempt
# clicked: 349 times.
# Click attempt
# clicked: 350 times.
# Click attempt
# clicked: 351 times.
# Click attempt
# clicked: 352 times.
# Click attempt
# clicked: 353 times.
# Click attempt
# clicked: 354 times.
# Click attempt
# clicked: 355 times.
# Click attempt
# clicked: 356 times.
# Click attempt
# clicked: 357 times.
# Click attempt
# clicked: 358 times.
# Click attempt
# clicked: 359 times.
# Click attempt
# clicked: 360 times.
# Click attempt
# clicked: 361 times.
# Click attempt
# clicked: 362 times.
# Click attempt
# clicked: 363 times.
# Click attempt
# clicked: 364 times.
# Click attempt
# clicked: 365 times.
# Click attempt
# clicked: 366 times.
# Click attempt
# clicked: 367 times.
# Click attempt
# clicked: 368 times.
# Click attempt
# clicked: 369 times.
# Click attempt
# clicked: 370 times.
# Click attempt
# clicked: 371 times.
# Click attempt
# clicked: 372 times.
# Click attempt
# clicked: 373 times.
# Click attempt
# clicked: 374 times.
# Click attempt
# clicked: 375 times.
# Click attempt
# clicked: 376 times.
# Click attempt
# clicked: 377 times.
# Click attempt
# clicked: 378 times.
# Click attempt
# clicked: 379 times.
# Click attempt
# clicked: 380 times.
# Click attempt
# clicked: 381 times.
# Click attempt
# clicked: 382 times.
# Click attempt
# clicked: 383 times.
# Click attempt
# clicked: 384 times.
# Click attempt
# clicked: 385 times.
# Click attempt
# clicked: 386 times.
# Click attempt
# clicked: 387 times.
# Click attempt
# clicked: 388 times.
# Click attempt
# clicked: 389 times.
# Click attempt
# clicked: 390 times.
# Click attempt
# clicked: 391 times.
# Click attempt
# clicked: 392 times.
# Click attempt
# clicked: 393 times.
# Click attempt
# clicked: 394 times.
# Click attempt
# clicked: 395 times.
# Click attempt
# clicked: 396 times.
# Click attempt
# clicked: 397 times.
# Click attempt
# clicked: 398 times.
# Click attempt
# clicked: 399 times.
# Click attempt
# clicked: 400 times.
# Click attempt
# clicked: 401 times.
# Click attempt
# clicked: 402 times.
# Click attempt
# clicked: 403 times.
# Click attempt
# clicked: 404 times.
# Click attempt
# clicked: 405 times.
# Click attempt
# clicked: 406 times.
# Click attempt
# clicked: 407 times.
# Click attempt
# clicked: 408 times.
# Click attempt
# clicked: 409 times.
# Click attempt
# clicked: 410 times.
# Click attempt
# clicked: 411 times.
# Click attempt
# clicked: 412 times.
# Click attempt
# clicked: 413 times.
# Click attempt
# clicked: 414 times.
# Click attempt
# clicked: 415 times.
# Click attempt
# clicked: 416 times.
# Click attempt
# clicked: 417 times.
# Click attempt
# clicked: 418 times.
# Click attempt
# clicked: 419 times.
# Click attempt
# clicked: 420 times.
# Click attempt
# clicked: 421 times.
# Click attempt
# clicked: 422 times.
# Click attempt
# clicked: 423 times.
# Click attempt
# clicked: 424 times.
# Click attempt
# clicked: 425 times.
# Click attempt
# clicked: 426 times.
# Click attempt
# clicked: 427 times.
# Click attempt
# clicked: 428 times.
# Click attempt
# clicked: 429 times.
# Click attempt
# clicked: 430 times.
# Click attempt
# clicked: 431 times.
# Click attempt
# clicked: 432 times.
# Click attempt
# clicked: 433 times.
# Click attempt
# clicked: 434 times.
# Click attempt
# clicked: 435 times.
# Click attempt
# clicked: 436 times.
# Click attempt
# clicked: 437 times.
# Click attempt
# clicked: 438 times.
# Click attempt
# clicked: 439 times.
# Click attempt
# clicked: 440 times.
# Click attempt
# clicked: 441 times.
# Click attempt
# clicked: 442 times.
# Click attempt
# clicked: 443 times.
# Click attempt
# clicked: 444 times.
# Click attempt
# clicked: 445 times.
# Click attempt
# clicked: 446 times.
# Click attempt
# clicked: 447 times.
# Click attempt
# clicked: 448 times.
# Click attempt
# clicked: 449 times.
# Click attempt
# clicked: 450 times.
# Click attempt
# clicked: 451 times.
# Click attempt
# clicked: 452 times.
# Click attempt
# clicked: 453 times.
# Click attempt
# clicked: 454 times.
# Click attempt
# clicked: 455 times.
# Click attempt
# clicked: 456 times.
# Click attempt
# clicked: 457 times.
# Click attempt
# clicked: 458 times.
# Click attempt
# clicked: 459 times.
# Click attempt
# clicked: 460 times.
# Click attempt
# clicked: 461 times.
# Click attempt
# clicked: 462 times.
# Click attempt
# clicked: 463 times.
# Click attempt
# clicked: 464 times.
# Click attempt
# clicked: 465 times.
# Click attempt
# clicked: 466 times.
# Click attempt
# clicked: 467 times.
# Click attempt
# clicked: 468 times.
# Click attempt
# clicked: 469 times.
# Click attempt
# clicked: 470 times.
# Click attempt
# clicked: 471 times.
# Click attempt
# clicked: 472 times.
# Click attempt
# clicked: 473 times.
# Click attempt
# clicked: 474 times.
# Click attempt
# clicked: 475 times.
# Click attempt
# clicked: 476 times.
# Click attempt
# clicked: 477 times.
# Click attempt
# clicked: 478 times.
# Click attempt
# clicked: 479 times.
# Click attempt
# clicked: 480 times.
# Click attempt
# clicked: 481 times.
# Click attempt
# clicked: 482 times.
# Click attempt
# clicked: 483 times.
# Click attempt
# clicked: 484 times.
# Click attempt
# clicked: 485 times.
# Click attempt
# clicked: 486 times.
# Click attempt
# clicked: 487 times.
# Click attempt
# clicked: 488 times.
# Click attempt
# clicked: 489 times.
# Click attempt
# clicked: 490 times.
# Click attempt
# clicked: 491 times.
# Click attempt
# clicked: 492 times.
# Click attempt
# clicked: 493 times.
# Click attempt
# clicked: 494 times.
# Click attempt
# clicked: 495 times.
# Click attempt
# clicked: 496 times.
# Click attempt
# clicked: 497 times.
# Click attempt
# clicked: 498 times.
# Click attempt
# clicked: 499 times.
# Click attempt
# clicked: 500 times.
# Click attempt
# clicked: 501 times.
# Click attempt
# clicked: 502 times.
# Click attempt
# clicked: 503 times.
# Click attempt
# clicked: 504 times.
# Click attempt
# clicked: 505 times.
# Click attempt
# clicked: 506 times.
# Click attempt
# clicked: 507 times.
# Click attempt
# clicked: 508 times.
# Click attempt
# clicked: 509 times.
# Click attempt
# clicked: 510 times.
# Click attempt
# clicked: 511 times.
# Click attempt
# clicked: 512 times.
# Click attempt
# clicked: 513 times.
# Click attempt
# clicked: 514 times.
# Click attempt
# clicked: 515 times.
# Click attempt
# clicked: 516 times.
# Click attempt
# clicked: 517 times.
# Click attempt
# clicked: 518 times.
# Click attempt
# clicked: 519 times.
# Click attempt
# clicked: 520 times.
# Click attempt
# clicked: 521 times.
# Click attempt
# clicked: 522 times.
# Click attempt
# clicked: 523 times.
# Click attempt
# clicked: 524 times.
# Click attempt
# clicked: 525 times.
# Click attempt
# clicked: 526 times.
# Click attempt
# clicked: 527 times.
# Click attempt
# clicked: 528 times.
# Click attempt
# clicked: 529 times.
# Click attempt
# clicked: 530 times.
# Click attempt
# clicked: 531 times.
# Click attempt
# clicked: 532 times.
# Click attempt
# clicked: 533 times.
# Click attempt
# clicked: 534 times.
# Click attempt
# clicked: 535 times.
# Click attempt
# clicked: 536 times.
# Click attempt
# clicked: 537 times.
# Click attempt
# clicked: 538 times.
# Click attempt
# clicked: 539 times.
# Click attempt
# clicked: 540 times.
# Click attempt
# clicked: 541 times.
# Click attempt
# clicked: 542 times.
# Click attempt
# clicked: 543 times.
# Click attempt
# clicked: 544 times.
# Click attempt
# clicked: 545 times.
# Click attempt
# clicked: 546 times.
# Click attempt
# clicked: 547 times.
# Click attempt
# clicked: 548 times.
# Click attempt
# clicked: 549 times.
# Click attempt
# clicked: 550 times.
# Click attempt
# clicked: 551 times.
# Click attempt
# clicked: 552 times.
# Click attempt
# clicked: 553 times.
# Click attempt
# clicked: 554 times.
# Click attempt
# clicked: 555 times.
# Click attempt
# clicked: 556 times.
# Click attempt
# clicked: 557 times.
# Click attempt
# clicked: 558 times.
# Click attempt
# clicked: 559 times.
# Click attempt
# clicked: 560 times.
# Click attempt
# clicked: 561 times.
# Click attempt
# clicked: 562 times.
# Click attempt
# clicked: 563 times.
# Click attempt
# clicked: 564 times.
# Click attempt
# clicked: 565 times.
# Click attempt
# clicked: 566 times.
# Click attempt
# clicked: 567 times.
# Click attempt
# clicked: 568 times.
# Click attempt
# clicked: 569 times.
# Click attempt
# clicked: 570 times.
# Click attempt
# clicked: 571 times.
# Click attempt
# clicked: 572 times.
# Click attempt
# clicked: 573 times.
# Click attempt
# clicked: 574 times.
# Click attempt
# clicked: 575 times.
# Click attempt
# clicked: 576 times.
# Click attempt
# clicked: 577 times.
# Click attempt
# clicked: 578 times.
# Click attempt
# clicked: 579 times.
# Click attempt
# clicked: 580 times.
# Click attempt
# clicked: 581 times.
# Click attempt
# clicked: 582 times.
# Click attempt
# clicked: 583 times.
# Click attempt
# clicked: 584 times.
# Click attempt
# clicked: 585 times.
# Click attempt
# clicked: 586 times.
# Click attempt
# clicked: 587 times.
# Click attempt
# clicked: 588 times.
# Click attempt
# clicked: 589 times.
# Click attempt
# clicked: 590 times.
# Click attempt
# clicked: 591 times.
# Click attempt
# clicked: 592 times.
# Click attempt
# clicked: 593 times.
# Click attempt
# clicked: 594 times.
# Click attempt
# clicked: 595 times.
# Click attempt
# clicked: 596 times.
# Click attempt
# clicked: 597 times.
# Click attempt
# clicked: 598 times.
# Click attempt
# clicked: 599 times.
# Click attempt
# clicked: 600 times.
# Click attempt
# clicked: 601 times.
# Click attempt
# clicked: 602 times.
# Click attempt
# clicked: 603 times.
# Click attempt
# clicked: 604 times.
# Click attempt
# clicked: 605 times.
# Click attempt
# clicked: 606 times.
# Click attempt
# clicked: 607 times.
# Click attempt
# clicked: 608 times.
# Click attempt
# clicked: 609 times.
# Click attempt
# clicked: 610 times.
# Click attempt
# clicked: 611 times.
# Click attempt
# clicked: 612 times.
# Click attempt
# clicked: 613 times.
# Click attempt
# clicked: 614 times.
# Click attempt
# clicked: 615 times.
# Click attempt
# clicked: 616 times.
# Click attempt
# clicked: 617 times.
# Click attempt
# clicked: 618 times.
# Click attempt
# clicked: 619 times.
# Click attempt
# clicked: 620 times.
# Click attempt
# clicked: 621 times.
# Click attempt
# clicked: 622 times.
# Click attempt
# clicked: 623 times.
# Click attempt
# clicked: 624 times.
# Click attempt
# clicked: 625 times.
# Click attempt
# clicked: 626 times.
# Click attempt
# clicked: 627 times.
# Click attempt
# clicked: 628 times.
# Click attempt
# clicked: 629 times.
# Click attempt
# clicked: 630 times.
# Click attempt
# clicked: 631 times.
# Click attempt
# clicked: 632 times.
# Click attempt
# clicked: 633 times.
# Click attempt
# clicked: 634 times.
# Click attempt
# clicked: 635 times.
# Click attempt
# clicked: 636 times.
# Click attempt
# clicked: 637 times.
# Click attempt
# clicked: 638 times.
# Click attempt
# clicked: 639 times.
# Click attempt
# clicked: 640 times.
# Click attempt
# clicked: 641 times.
# Click attempt
# clicked: 642 times.
# Click attempt
# clicked: 643 times.
# Click attempt
# clicked: 644 times.
# Click attempt
# clicked: 645 times.
# Click attempt
# clicked: 646 times.
# Click attempt
# clicked: 647 times.
# Click attempt
# clicked: 648 times.
# Click attempt
# clicked: 649 times.
# Click attempt
# clicked: 650 times.
# Click attempt
# clicked: 651 times.
# Click attempt
# clicked: 652 times.
# Click attempt
# clicked: 653 times.
# Click attempt
# clicked: 654 times.
# Click attempt
# clicked: 655 times.
# Click attempt
# clicked: 656 times.
# Click attempt
# clicked: 657 times.
# Click attempt
# clicked: 658 times.
# Click attempt
# clicked: 659 times.
# Click attempt
# clicked: 660 times.
# Click attempt
# clicked: 661 times.
# Click attempt
# clicked: 662 times.
# Click attempt
# clicked: 663 times.
# Click attempt
# clicked: 664 times.
# Click attempt
# clicked: 665 times.
# Click attempt
# clicked: 666 times.
# Click attempt
# clicked: 667 times.
# Click attempt
# clicked: 668 times.
# Click attempt
# clicked: 669 times.
# Click attempt
# clicked: 670 times.
# Click attempt
# clicked: 671 times.
# Click attempt
# clicked: 672 times.
# Click attempt
# clicked: 673 times.
# Click attempt
# clicked: 674 times.
# Click attempt
# clicked: 675 times.
# Click attempt
# clicked: 676 times.
# Click attempt
# clicked: 677 times.
# Click attempt
# clicked: 678 times.
# Click attempt
# clicked: 679 times.
# Click attempt
# clicked: 680 times.
# Click attempt
# clicked: 681 times.
# Click attempt
# clicked: 682 times.
# Click attempt
# clicked: 683 times.
# Click attempt
# clicked: 684 times.
# Click attempt
# clicked: 685 times.
# Click attempt
# clicked: 686 times.
# Click attempt
# clicked: 687 times.
# Click attempt
# clicked: 688 times.
# Click attempt
# clicked: 689 times.
# Click attempt
# clicked: 690 times.
# Click attempt
# clicked: 691 times.
# Click attempt
# clicked: 692 times.
# Click attempt
# clicked: 693 times.
# Click attempt
# clicked: 694 times.
# Click attempt
# clicked: 695 times.
# Click attempt
# clicked: 696 times.
# Click attempt
# clicked: 697 times.
# Click attempt
# clicked: 698 times.
# Click attempt
# clicked: 699 times.
# Click attempt
# clicked: 700 times.
# Click attempt
# clicked: 701 times.
# Click attempt
# clicked: 702 times.
# Click attempt
# clicked: 703 times.
# Click attempt
# clicked: 704 times.
# Click attempt
# clicked: 705 times.
# Click attempt
# clicked: 706 times.
# Click attempt
# clicked: 707 times.
# Click attempt
# clicked: 708 times.
# Click attempt
# clicked: 709 times.
# Click attempt
# clicked: 710 times.
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# clicked: 6 times.
# Click attempt
# clicked: 7 times.
# Click attempt
# clicked: 8 times.
# Click attempt
# clicked: 9 times.
# Click attempt
# clicked: 10 times.
# Click attempt
# clicked: 11 times.
# Click attempt
# clicked: 12 times.
# Click attempt
# clicked: 13 times.
# Click attempt
# clicked: 14 times.
# Click attempt
# clicked: 15 times.
# Click attempt
# clicked: 16 times.
# Click attempt
# clicked: 17 times.
# Click attempt
# clicked: 18 times.
# Click attempt
# clicked: 19 times.
# Click attempt
# clicked: 20 times.
# Click attempt
# clicked: 21 times.
# Click attempt
# clicked: 22 times.
# Click attempt
# clicked: 23 times.
# Click attempt
# clicked: 24 times.
# Click attempt
# clicked: 25 times.
# Click attempt
# clicked: 26 times.
# Click attempt
# clicked: 27 times.
# Click attempt
# clicked: 28 times.
# Click attempt
# clicked: 29 times.
# Click attempt
# clicked: 30 times.
# Click attempt
# clicked: 31 times.
# Click attempt
# clicked: 32 times.
# Click attempt
# clicked: 33 times.
# Click attempt
# clicked: 34 times.
# Click attempt
# clicked: 35 times.
# Click attempt
# clicked: 36 times.
# Click attempt
# clicked: 37 times.
# Click attempt
# clicked: 38 times.
# Click attempt
# clicked: 39 times.
# Click attempt
# clicked: 40 times.
# Click attempt
# clicked: 41 times.
# Click attempt
# clicked: 42 times.
# Click attempt
# clicked: 43 times.
# Click attempt
# clicked: 44 times.
# Click attempt
# clicked: 45 times.
# Click attempt
# clicked: 46 times.
# Click attempt
# clicked: 47 times.
# Click attempt
# clicked: 48 times.
# Click attempt
# clicked: 49 times.
# Click attempt
# clicked: 50 times.
# Click attempt
# clicked: 51 times.
# Click attempt
# clicked: 52 times.
# Click attempt
# clicked: 53 times.
# Click attempt
# clicked: 54 times.
# Click attempt
# clicked: 55 times.
# Click attempt
# clicked: 56 times.
# Click attempt
# clicked: 57 times.
# Click attempt
# clicked: 58 times.
# Click attempt
# clicked: 59 times.
# Click attempt
# clicked: 60 times.
# Click attempt
# clicked: 61 times.
# Click attempt
# clicked: 62 times.
# Click attempt
# clicked: 63 times.
# Click attempt
# clicked: 64 times.
# Click attempt
# clicked: 65 times.
# Click attempt
# clicked: 66 times.
# Click attempt
# clicked: 67 times.
# Click attempt
# clicked: 68 times.
# Click attempt
# clicked: 69 times.
# Click attempt
# clicked: 70 times.
# Click attempt
# clicked: 71 times.
# Click attempt
# clicked: 72 times.
# Click attempt
# clicked: 73 times.
# Click attempt
# clicked: 74 times.
# Click attempt
# clicked: 75 times.
# Click attempt
# clicked: 76 times.
# Click attempt
# clicked: 77 times.
# Click attempt
# clicked: 78 times.
# Click attempt
# clicked: 79 times.
# Click attempt
# clicked: 80 times.
# Click attempt
# clicked: 81 times.
# Click attempt
# clicked: 82 times.
# Click attempt
# clicked: 83 times.
# Click attempt
# clicked: 84 times.
# Click attempt
# clicked: 85 times.
# Click attempt
# clicked: 86 times.
# Click attempt
# clicked: 87 times.
# Click attempt
# clicked: 88 times.
# Click attempt
# clicked: 89 times.
# Click attempt
# clicked: 90 times.
# Click attempt
# clicked: 91 times.
# Click attempt
# clicked: 92 times.
# Click attempt
# clicked: 93 times.
# Click attempt
# clicked: 94 times.
# Click attempt
# clicked: 95 times.
# Click attempt
# clicked: 96 times.
# Click attempt
# clicked: 97 times.
# Click attempt
# clicked: 98 times.
# Click attempt
# clicked: 99 times.
# Click attempt
# clicked: 100 times.
# Click attempt
# clicked: 101 times.
# Click attempt
# clicked: 102 times.
# Click attempt
# clicked: 103 times.
# Click attempt
# clicked: 104 times.
# Click attempt
# clicked: 105 times.
# Click attempt
# clicked: 106 times.
# Click attempt
# clicked: 107 times.
# Click attempt
# clicked: 108 times.
# Click attempt
# clicked: 109 times.
# Click attempt
# clicked: 110 times.
# Click attempt
# clicked: 111 times.
# Click attempt
# clicked: 112 times.
# Click attempt
# clicked: 113 times.
# Click attempt
# clicked: 114 times.
# Click attempt
# clicked: 115 times.
# Click attempt
# clicked: 116 times.
# Click attempt
# clicked: 117 times.
# Click attempt
# clicked: 118 times.
# Click attempt
# clicked: 119 times.
# Click attempt
# clicked: 120 times.
# Click attempt
# clicked: 121 times.
# Click attempt
# clicked: 122 times.
# Click attempt
# clicked: 123 times.
# Click attempt
# clicked: 124 times.
# Click attempt
# clicked: 125 times.
# Click attempt
# clicked: 126 times.
# Click attempt
# clicked: 127 times.
# Click attempt
# clicked: 128 times.
# Click attempt
# clicked: 129 times.
# Click attempt
# clicked: 130 times.
# Click attempt
# clicked: 131 times.
# Click attempt
# clicked: 132 times.
# Click attempt
# clicked: 133 times.
# Click attempt
# clicked: 134 times.
# Click attempt
# clicked: 135 times.
# Click attempt
# clicked: 136 times.
# Click attempt
# clicked: 137 times.
# Click attempt
# clicked: 138 times.
# Click attempt
# clicked: 139 times.
# Click attempt
# clicked: 140 times.
# Click attempt
# clicked: 141 times.
# Click attempt
# clicked: 142 times.
# Click attempt
# clicked: 143 times.
# Click attempt
# clicked: 144 times.
# Click attempt
# clicked: 145 times.
# Click attempt
# clicked: 146 times.
# Click attempt
# clicked: 147 times.
# Click attempt
# clicked: 148 times.
# Click attempt
# clicked: 149 times.
# Click attempt
# clicked: 150 times.
# Click attempt
# clicked: 151 times.
# Click attempt
# clicked: 152 times.
# Click attempt
# clicked: 153 times.
# Click attempt
# clicked: 154 times.
# Click attempt
# clicked: 155 times.
# Click attempt
# clicked: 156 times.
# Click attempt
# clicked: 157 times.
# Click attempt
# clicked: 158 times.
# Click attempt
# clicked: 159 times.
# Click attempt
# clicked: 160 times.
# Click attempt
# clicked: 161 times.
# Click attempt
# clicked: 162 times.
# Click attempt
# clicked: 163 times.
# Click attempt
# clicked: 164 times.
# Click attempt
# clicked: 165 times.
# Click attempt
# clicked: 166 times.
# Click attempt
# clicked: 167 times.
# Click attempt
# clicked: 168 times.
# Click attempt
# clicked: 169 times.
# Click attempt
# clicked: 170 times.
# Click attempt
# clicked: 171 times.
# Click attempt
# clicked: 172 times.
# Click attempt
# clicked: 173 times.
# Click attempt
# clicked: 174 times.
# Click attempt
# clicked: 175 times.
# Click attempt
# clicked: 176 times.
# Click attempt
# clicked: 177 times.
# Click attempt
# clicked: 178 times.
# Click attempt
# clicked: 179 times.
# Click attempt
# clicked: 180 times.
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# clicked: 6 times.
# Click attempt
# clicked: 7 times.
# Click attempt
# clicked: 8 times.
# Click attempt
# clicked: 9 times.
# Click attempt
# clicked: 10 times.
# Click attempt
# clicked: 11 times.
# Click attempt
# clicked: 12 times.
# Click attempt
# clicked: 13 times.
# Click attempt
# clicked: 14 times.
# Click attempt
# clicked: 15 times.
# Click attempt
# clicked: 16 times.
# Click attempt
# clicked: 17 times.
# Click attempt
# clicked: 18 times.
# Click attempt
# clicked: 19 times.
# Click attempt
# clicked: 20 times.
# Click attempt
# clicked: 21 times.
# Click attempt
# clicked: 22 times.
# Click attempt
# clicked: 23 times.
# Click attempt
# clicked: 24 times.
# Click attempt
# clicked: 25 times.
# Click attempt
# clicked: 26 times.
# Click attempt
# clicked: 27 times.
# Click attempt
# clicked: 28 times.
# Click attempt
# clicked: 29 times.
# Click attempt
# clicked: 30 times.
# Click attempt
# clicked: 31 times.
# Click attempt
# clicked: 32 times.
# Click attempt
# clicked: 33 times.
# Click attempt
# clicked: 34 times.
# Click attempt
# clicked: 35 times.
# Click attempt
# clicked: 36 times.
# Click attempt
# clicked: 37 times.
# Click attempt
# clicked: 38 times.
# Click attempt
# clicked: 39 times.
# Click attempt
# clicked: 40 times.
# Click attempt
# clicked: 41 times.
# Click attempt
# clicked: 42 times.
# Click attempt
# clicked: 43 times.
# Click attempt
# clicked: 44 times.
# Click attempt
# clicked: 45 times.
# Click attempt
# clicked: 46 times.
# Click attempt
# clicked: 47 times.
# Click attempt
# clicked: 48 times.
# Click attempt
# clicked: 49 times.
# Click attempt
# clicked: 50 times.
# Click attempt
# clicked: 51 times.
# Click attempt
# clicked: 52 times.
# Click attempt
# clicked: 53 times.
# Click attempt
# clicked: 54 times.
# Click attempt
# clicked: 55 times.
# Click attempt
# clicked: 56 times.
# Click attempt
# clicked: 57 times.
# Click attempt
# clicked: 58 times.
# Click attempt
# clicked: 59 times.
# Click attempt
# clicked: 60 times.
# Click attempt
# clicked: 61 times.
# Click attempt
# clicked: 62 times.
# Click attempt
# clicked: 63 times.
# Click attempt
# clicked: 64 times.
# Click attempt
# clicked: 65 times.
# Click attempt
# clicked: 66 times.
# Click attempt
# clicked: 67 times.
# Click attempt
# clicked: 68 times.
# Click attempt
# clicked: 69 times.
# Click attempt
# clicked: 70 times.
# Click attempt
# clicked: 71 times.
# Click attempt
# clicked: 72 times.
# Click attempt
# clicked: 73 times.
# Click attempt
# clicked: 74 times.
# Click attempt
# clicked: 75 times.
# Click attempt
# clicked: 76 times.
# Click attempt
# clicked: 77 times.
# Click attempt
# clicked: 78 times.
# Click attempt
# clicked: 79 times.
# Click attempt
# clicked: 80 times.
# Click attempt
# clicked: 81 times.
# Click attempt
# clicked: 82 times.
# Click attempt
# clicked: 83 times.
# Click attempt
# clicked: 84 times.
# Click attempt
# clicked: 85 times.
# Click attempt
# clicked: 86 times.
# Click attempt
# clicked: 87 times.
# Click attempt
# clicked: 88 times.
# Click attempt
# clicked: 89 times.
# Click attempt
# clicked: 90 times.
# Click attempt
# clicked: 91 times.
# Click attempt
# clicked: 92 times.
# Click attempt
# clicked: 93 times.
# Click attempt
# clicked: 94 times.
# Click attempt
# clicked: 95 times.
# Click attempt
# clicked: 96 times.
# Click attempt
# clicked: 97 times.
# Click attempt
# clicked: 98 times.
# Click attempt
# clicked: 99 times.
# Click attempt
# clicked: 100 times.
# Click attempt
# clicked: 101 times.
# Click attempt
# clicked: 102 times.
# Click attempt
# clicked: 103 times.
# Click attempt
# clicked: 104 times.
# Click attempt
# clicked: 105 times.
# Click attempt
# clicked: 106 times.
# Click attempt
# clicked: 107 times.
# Click attempt
# clicked: 108 times.
# Click attempt
# clicked: 109 times.
# Click attempt
# clicked: 110 times.
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# clicked: 6 times.
# Click attempt
# clicked: 7 times.
# Click attempt
# clicked: 8 times.
# Click attempt
# clicked: 9 times.
# Click attempt
# clicked: 10 times.
# Click attempt
# clicked: 11 times.
# Click attempt
# clicked: 12 times.
# Click attempt
# clicked: 13 times.
# Click attempt
# clicked: 14 times.
# Click attempt
# clicked: 15 times.
# Click attempt
# clicked: 16 times.
# Click attempt
# clicked: 17 times.
# Click attempt
# clicked: 18 times.
# Click attempt
# clicked: 19 times.
# Click attempt
# clicked: 20 times.
# Click attempt
# clicked: 21 times.
# Click attempt
# clicked: 22 times.
# Click attempt
# clicked: 23 times.
# Click attempt
# clicked: 24 times.
# Click attempt
# clicked: 25 times.
# Click attempt
# clicked: 26 times.
# Click attempt
# clicked: 27 times.
# Click attempt
# clicked: 28 times.
# Click attempt
# clicked: 29 times.
# Click attempt
# clicked: 30 times.
# Click attempt
# clicked: 31 times.
# Click attempt
# clicked: 32 times.
# Click attempt
# clicked: 33 times.
# Click attempt
# clicked: 34 times.
# Click attempt
# clicked: 35 times.
# Click attempt
# clicked: 36 times.
# Click attempt
# clicked: 37 times.
# Click attempt
# clicked: 38 times.
# Click attempt
# clicked: 39 times.
# Click attempt
# clicked: 40 times.
# Click attempt
# clicked: 41 times.
# Click attempt
# clicked: 42 times.
# Click attempt
# clicked: 43 times.
# Click attempt
# clicked: 44 times.
# Click attempt
# clicked: 45 times.
# Click attempt
# clicked: 46 times.
# Click attempt
# clicked: 47 times.
# Click attempt
# clicked: 48 times.
# Click attempt
# clicked: 49 times.
# Click attempt
# clicked: 50 times.
# Click attempt
# clicked: 51 times.
# Click attempt
# clicked: 52 times.
# Click attempt
# clicked: 53 times.
# Click attempt
# clicked: 54 times.
# Click attempt
# clicked: 55 times.
# Click attempt
# clicked: 56 times.
# Click attempt
# clicked: 57 times.
# Click attempt
# clicked: 58 times.
# Click attempt
# clicked: 59 times.
# Click attempt
# clicked: 60 times.
# Click attempt
# clicked: 61 times.
# Click attempt
# clicked: 62 times.
# Click attempt
# clicked: 63 times.
# Click attempt
# clicked: 64 times.
# Click attempt
# clicked: 65 times.
# Click attempt
# clicked: 66 times.
# Click attempt
# clicked: 67 times.
# Click attempt
# clicked: 68 times.
# Click attempt
# clicked: 69 times.
# Click attempt
# clicked: 70 times.
# Click attempt
# clicked: 71 times.
# Click attempt
# clicked: 72 times.
# Click attempt
# clicked: 73 times.
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# clicked: 6 times.
# Click attempt
# clicked: 7 times.
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# clicked: 6 times.
# Click attempt
# clicked: 7 times.
# Click attempt
# clicked: 8 times.
# Click attempt
# clicked: 9 times.
# Click attempt
# clicked: 10 times.
# Click attempt
# clicked: 11 times.
# Click attempt
# clicked: 12 times.
# Click attempt
# clicked: 13 times.
# Click attempt
# clicked: 14 times.
# Click attempt
# clicked: 15 times.
# Click attempt
# clicked: 16 times.
# Click attempt
# clicked: 17 times.
# Click attempt
# clicked: 18 times.
# Click attempt
# clicked: 19 times.
# Click attempt
# clicked: 20 times.
# Click attempt
# clicked: 21 times.
# Click attempt
# clicked: 22 times.
# Click attempt
# clicked: 23 times.
# Click attempt
# clicked: 24 times.
# Click attempt
# clicked: 25 times.
# Click attempt
# clicked: 26 times.
# Click attempt
# clicked: 27 times.
# Click attempt
# clicked: 28 times.
# Click attempt
# clicked: 29 times.
# Click attempt
# clicked: 30 times.
# Click attempt
# clicked: 31 times.
# Click attempt
# clicked: 32 times.
# Click attempt
# clicked: 33 times.
# Click attempt
# clicked: 34 times.
# Click attempt
# clicked: 35 times.
# Click attempt
# clicked: 36 times.
# Click attempt
# clicked: 37 times.
# Click attempt
# clicked: 38 times.
# Click attempt
# clicked: 39 times.
# Click attempt
# clicked: 40 times.
# Click attempt
# clicked: 41 times.
# Click attempt
# clicked: 42 times.
# Click attempt
# clicked: 43 times.
# Click attempt
# clicked: 44 times.
# Click attempt
# clicked: 45 times.
# Click attempt
# clicked: 46 times.
# Click attempt
# clicked: 47 times.
# Click attempt
# clicked: 48 times.
# Click attempt
# clicked: 49 times.
# Click attempt
# clicked: 50 times.
# Click attempt
# clicked: 51 times.
# Click attempt
# clicked: 52 times.
# Click attempt
# clicked: 53 times.
# Click attempt
# clicked: 54 times.
# Click attempt
# clicked: 55 times.
# Click attempt
# clicked: 56 times.
# Click attempt
# clicked: 57 times.
# Click attempt
# clicked: 58 times.
# Click attempt
# clicked: 59 times.
# Click attempt
# clicked: 60 times.
# Click attempt
# clicked: 61 times.
# Click attempt
# clicked: 62 times.
# Click attempt
# clicked: 63 times.
# Click attempt
# clicked: 64 times.
# Click attempt
# clicked: 65 times.
# Click attempt
# clicked: 66 times.
# Click attempt
# clicked: 67 times.
# Click attempt
# clicked: 68 times.
# Click attempt
# clicked: 69 times.
# Click attempt
# clicked: 70 times.
# Click attempt
# clicked: 71 times.
# Click attempt
# clicked: 72 times.
# Click attempt
# clicked: 73 times.
# Click attempt
# clicked: 74 times.
# Click attempt
# clicked: 75 times.
# Click attempt
# clicked: 76 times.
# Click attempt
# clicked: 77 times.
# Click attempt
# clicked: 78 times.
# Click attempt
# clicked: 79 times.
# Click attempt
# clicked: 80 times.
# Click attempt
# clicked: 81 times.
# Click attempt
# clicked: 82 times.
# Click attempt
# clicked: 83 times.
# Click attempt
# clicked: 84 times.
# Click attempt
# clicked: 85 times.
# Click attempt
# clicked: 86 times.
# Click attempt
# clicked: 87 times.
# Click attempt
# clicked: 88 times.
# Click attempt
# clicked: 89 times.
# Click attempt
# clicked: 90 times.
# Click attempt
# clicked: 91 times.
# Click attempt
# clicked: 92 times.
# Click attempt
# clicked: 93 times.
# Click attempt
# clicked: 94 times.
# Click attempt
# clicked: 95 times.
# Click attempt
# clicked: 96 times.
# Click attempt
# clicked: 97 times.
# Click attempt
# clicked: 98 times.
# Click attempt
# clicked: 99 times.
# Click attempt
# clicked: 100 times.
# Click attempt
# clicked: 101 times.
# Click attempt
# clicked: 102 times.
# Click attempt
# clicked: 103 times.
# Click attempt
# clicked: 104 times.
# Click attempt
# clicked: 105 times.
# Click attempt
# clicked: 106 times.
# Click attempt
# clicked: 107 times.
# Click attempt
# clicked: 108 times.
# Click attempt
# clicked: 109 times.
# Click attempt
# clicked: 110 times.
# Click attempt
# clicked: 111 times.
# Click attempt
# clicked: 112 times.
# Click attempt
# clicked: 113 times.
# Click attempt
# clicked: 114 times.
# Click attempt
# clicked: 115 times.
# Click attempt
# clicked: 116 times.
# Click attempt
# clicked: 117 times.
# Click attempt
# clicked: 118 times.
# Click attempt
# clicked: 119 times.
# Click attempt
# clicked: 120 times.
# Click attempt
# clicked: 121 times.
# Click attempt
# clicked: 122 times.
# Click attempt
# clicked: 123 times.
# Click attempt
# clicked: 124 times.
# Click attempt
# clicked: 125 times.
# Click attempt
# clicked: 126 times.
# Click attempt
# clicked: 127 times.
# Click attempt
# clicked: 128 times.
# Click attempt
# clicked: 129 times.
# Click attempt
# clicked: 130 times.
# Click attempt
# clicked: 131 times.
# Click attempt
# clicked: 132 times.
# Click attempt
# clicked: 133 times.
# Click attempt
# clicked: 134 times.
# Click attempt
# clicked: 135 times.
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# clicked: 6 times.
# Click attempt
# clicked: 7 times.
# Click attempt
# clicked: 8 times.
# Click attempt
# clicked: 9 times.
# Click attempt
# clicked: 10 times.
# Click attempt
# clicked: 11 times.
# Click attempt
# clicked: 12 times.
# Click attempt
# clicked: 13 times.
# Click attempt
# clicked: 14 times.
# Click attempt
# clicked: 15 times.
# Click attempt
# clicked: 16 times.
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# clicked: 6 times.
# Click attempt
# clicked: 7 times.
# Click attempt
# clicked: 8 times.
# Click attempt
# clicked: 9 times.
# Click attempt
# clicked: 10 times.
# Click attempt
# clicked: 11 times.
# Click attempt
# clicked: 12 times.
# Click attempt
# clicked: 13 times.
# Click attempt
# clicked: 14 times.
# Click attempt
# clicked: 15 times.
# Click attempt
# clicked: 16 times.
# Click attempt
# clicked: 17 times.
# Click attempt
# clicked: 18 times.
# Click attempt
# clicked: 19 times.
# Click attempt
# clicked: 20 times.
# Click attempt
# clicked: 21 times.
# Click attempt
# clicked: 22 times.
# Click attempt
# clicked: 23 times.
# Click attempt
# clicked: 24 times.
# Click attempt
# clicked: 25 times.
# Click attempt
# clicked: 26 times.
# Click attempt
# clicked: 27 times.
# Click attempt
# clicked: 28 times.
# Click attempt
# clicked: 29 times.
# Click attempt
# clicked: 30 times.
# Click attempt
# clicked: 31 times.
# Click attempt
# clicked: 32 times.
# Click attempt
# clicked: 33 times.
# Click attempt
# clicked: 34 times.
# Click attempt
# clicked: 35 times.
# Click attempt
# clicked: 36 times.
# Click attempt
# clicked: 37 times.
# Click attempt
# clicked: 38 times.
# Click attempt
# clicked: 39 times.
# Click attempt
# clicked: 40 times.
# Click attempt
# clicked: 41 times.
# Click attempt
# clicked: 42 times.
# Click attempt
# clicked: 43 times.
# Click attempt
# clicked: 44 times.
# Click attempt
# clicked: 45 times.
# Click attempt
# clicked: 46 times.
# Click attempt
# clicked: 47 times.
# Click attempt
# clicked: 48 times.
# Click attempt
# clicked: 49 times.
# Click attempt
# clicked: 50 times.
# Click attempt
# clicked: 51 times.
# Click attempt
# clicked: 52 times.
# Click attempt
# clicked: 53 times.
# Click attempt
# clicked: 54 times.
# Click attempt
# clicked: 55 times.
# Click attempt
# clicked: 56 times.
# Click attempt
# clicked: 57 times.
# Click attempt
# clicked: 58 times.
# Click attempt
# clicked: 59 times.
# Click attempt
# clicked: 60 times.
# Click attempt
# clicked: 61 times.
# Click attempt
# clicked: 62 times.
# ...
# Click attempt
# clicked: 540 times.
# Click attempt
# clicked: 541 times.
# Click attempt
# clicked: 542 times.
# Click attempt
# clicked: 543 times.
# Click attempt
# clicked: 544 times.
# Click attempt
# clicked: 545 times.
# Click attempt
# clicked: 546 times.
# Click attempt
# clicked: 547 times.
# Click attempt
# clicked: 548 times.
# Click attempt
# clicked: 549 times.
# Click attempt
# clicked: 550 times.
# Click attempt
# clicked: 551 times.
# Click attempt
# clicked: 552 times.
# Click attempt
# clicked: 553 times.
# Click attempt
# clicked: 554 times.
# Click attempt
# clicked: 555 times.
# Click attempt
# clicked: 556 times.
# Click attempt
# clicked: 557 times.
# Click attempt
# clicked: 558 times.
# Click attempt
# clicked: 559 times.
# Click attempt
# clicked: 560 times.
# Click attempt
# clicked: 561 times.
# Click attempt
# clicked: 562 times.
# Click attempt
# clicked: 563 times.
# Click attempt
# clicked: 564 times.
# Click attempt
# clicked: 565 times.
# Click attempt
# clicked: 566 times.
# Click attempt
# clicked: 567 times.
# Click attempt
# clicked: 568 times.
# Click attempt
# clicked: 569 times.
# Click attempt
# clicked: 570 times.
# Click attempt
# clicked: 571 times.
# Click attempt
# clicked: 572 times.
# Click attempt
# clicked: 573 times.
# Click attempt
# clicked: 574 times.
# Click attempt
# clicked: 575 times.
# Click attempt
# clicked: 576 times.
# Click attempt
# clicked: 577 times.
# Click attempt
# clicked: 578 times.
# Click attempt
# clicked: 579 times.
# Click attempt
# clicked: 580 times.
# Click attempt
# clicked: 581 times.
# Click attempt
# clicked: 582 times.
# Click attempt
# clicked: 583 times.
# Click attempt
# clicked: 584 times.
# Click attempt
# clicked: 585 times.
# Click attempt
# clicked: 586 times.
# Click attempt
# clicked: 587 times.
# Click attempt
# clicked: 588 times.
# Click attempt
# clicked: 589 times.
# Click attempt
# clicked: 590 times.
# Click attempt
# clicked: 591 times.
# Click attempt
# clicked: 592 times.
# Click attempt
# clicked: 593 times.
# Click attempt
# clicked: 594 times.
# Click attempt
# clicked: 595 times.
# Click attempt
# clicked: 596 times.
# Click attempt
# clicked: 597 times.
# Click attempt
# clicked: 598 times.
# Click attempt
# clicked: 599 times.
# Click attempt
# clicked: 600 times.
# Click attempt
# clicked: 601 times.
# Click attempt
# clicked: 602 times.
# Click attempt
# clicked: 603 times.
# Click attempt
# clicked: 604 times.
# Click attempt
# clicked: 605 times.
# Click attempt
# clicked: 606 times.
# Click attempt
# clicked: 607 times.
# Click attempt
# clicked: 608 times.
# Click attempt
# clicked: 609 times.
# Click attempt
# clicked: 610 times.
# Click attempt
# clicked: 611 times.
# Click attempt
# clicked: 612 times.
# Click attempt
# clicked: 613 times.
# Click attempt
# clicked: 614 times.
# Click attempt
# clicked: 615 times.
# Click attempt
# clicked: 616 times.
# Click attempt
# clicked: 617 times.
# Click attempt
# clicked: 618 times.
# Click attempt
# clicked: 619 times.
# Click attempt
# clicked: 620 times.
# Click attempt
# clicked: 621 times.
# Click attempt
# clicked: 622 times.
# Click attempt
# clicked: 623 times.
# Click attempt
# clicked: 624 times.
# Click attempt
# clicked: 625 times.
# Click attempt
# clicked: 626 times.
# Click attempt
# clicked: 627 times.
# Click attempt
# clicked: 628 times.
# Click attempt
# clicked: 629 times.
# Click attempt
# clicked: 630 times.
# Click attempt
# clicked: 631 times.
# Click attempt
# clicked: 632 times.
# Click attempt
# clicked: 633 times.
# Click attempt
# clicked: 634 times.
# Click attempt
# clicked: 635 times.
# Click attempt
# clicked: 636 times.
# Click attempt
# clicked: 637 times.
# Click attempt
# clicked: 638 times.
# Click attempt
# clicked: 639 times.
# Click attempt
# clicked: 640 times.
# Click attempt
# clicked: 641 times.
# Click attempt
# clicked: 642 times.
# Click attempt
# clicked: 643 times.
# Click attempt
# clicked: 644 times.
# Click attempt
# clicked: 645 times.
# Click attempt
# clicked: 646 times.
# Click attempt
# clicked: 647 times.
# Click attempt
# clicked: 648 times.
# Click attempt
# clicked: 649 times.
# Click attempt
# clicked: 650 times.
# Click attempt
# clicked: 651 times.
# Click attempt
# clicked: 652 times.
# Click attempt
# clicked: 653 times.
# Click attempt
# clicked: 654 times.
# Click attempt
# clicked: 655 times.
# Click attempt
# clicked: 656 times.
# Click attempt
# clicked: 657 times.
# Click attempt
# clicked: 658 times.
# Click attempt
# clicked: 659 times.
# Click attempt
# clicked: 660 times.
# Click attempt
# clicked: 661 times.
# Click attempt
# clicked: 662 times.
# Click attempt
# clicked: 663 times.
# Click attempt
# clicked: 664 times.
# Click attempt
# clicked: 665 times.
# Click attempt
# clicked: 666 times.
# Click attempt
# clicked: 667 times.
# Click attempt
# clicked: 668 times.
# Click attempt
# clicked: 669 times.
# Click attempt
# clicked: 670 times.
# Click attempt
# clicked: 671 times.
# Click attempt
# clicked: 672 times.
# Click attempt
# clicked: 673 times.
# Click attempt
# clicked: 674 times.
# Click attempt
# clicked: 675 times.
# Click attempt
# clicked: 676 times.
# Click attempt
# clicked: 677 times.
# Click attempt
# clicked: 678 times.
# Click attempt
# clicked: 679 times.
# Click attempt
# clicked: 680 times.
# Click attempt
# clicked: 681 times.
# Click attempt
# clicked: 682 times.
# Click attempt
# clicked: 683 times.
# Click attempt
# clicked: 684 times.
# Click attempt
# clicked: 685 times.
# Click attempt
# clicked: 686 times.
# Click attempt
# clicked: 687 times.
# Click attempt
# clicked: 688 times.
# Click attempt
# clicked: 689 times.
# Click attempt
# clicked: 690 times.
# Click attempt
# clicked: 691 times.
# Click attempt
# clicked: 692 times.
# Click attempt
# clicked: 693 times.
# Click attempt
# clicked: 694 times.
# Click attempt
# clicked: 695 times.
# Click attempt
# clicked: 696 times.
# Click attempt
# clicked: 697 times.
# Click attempt
# clicked: 698 times.
# Click attempt
# clicked: 699 times.
# Click attempt
# clicked: 700 times.
# Click attempt
# clicked: 701 times.
# Click attempt
# clicked: 702 times.
# Click attempt
# clicked: 703 times.
# Click attempt
# clicked: 704 times.
# Click attempt
# clicked: 705 times.
# Click attempt
# clicked: 706 times.
# Click attempt
# clicked: 707 times.
# Click attempt
# clicked: 708 times.
# Click attempt
# clicked: 709 times.
# Click attempt
# clicked: 710 times.
# Click attempt
# clicked: 711 times.
# Click attempt
# clicked: 712 times.
# Click attempt
# clicked: 713 times.
# Click attempt
# clicked: 714 times.
# Click attempt
# clicked: 715 times.
# Click attempt
# clicked: 716 times.
# Click attempt
# clicked: 717 times.
# Click attempt
# clicked: 718 times.
# Click attempt
# clicked: 719 times.
# Click attempt
# clicked: 720 times.
# Click attempt
# clicked: 721 times.
# Click attempt
# clicked: 722 times.
# Click attempt
# clicked: 723 times.
# Click attempt
# clicked: 724 times.
# Click attempt
# clicked: 725 times.
# Click attempt
# clicked: 726 times.
# Click attempt
# clicked: 727 times.
# Click attempt
# clicked: 728 times.
# Click attempt
# clicked: 729 times.
# Click attempt
# clicked: 730 times.
# Click attempt
# clicked: 731 times.
# Click attempt
# clicked: 732 times.
# Click attempt
# clicked: 733 times.
# Click attempt
# clicked: 734 times.
# Click attempt
# clicked: 735 times.
# Click attempt
# clicked: 736 times.
# Click attempt
# clicked: 737 times.
# Click attempt
# clicked: 738 times.
# Click attempt
# clicked: 739 times.
# Click attempt
# clicked: 740 times.
# Click attempt
# clicked: 741 times.
# Click attempt
# clicked: 742 times.
# Click attempt
# clicked: 743 times.
# Click attempt
# clicked: 744 times.
# Click attempt
# clicked: 745 times.
# Click attempt
# clicked: 746 times.
# Click attempt
# clicked: 747 times.
# Click attempt
# clicked: 748 times.
# Click attempt
# clicked: 749 times.
# Click attempt
# clicked: 750 times.
# Click attempt
# clicked: 751 times.
# Click attempt
# clicked: 752 times.
# Click attempt
# clicked: 753 times.
# Click attempt
# clicked: 754 times.
# Click attempt
# clicked: 755 times.
# Click attempt
# clicked: 756 times.
# Click attempt
# clicked: 757 times.
# Click attempt
# clicked: 758 times.
# Click attempt
# clicked: 759 times.
# Click attempt
# clicked: 760 times.
# Click attempt
# clicked: 761 times.
# Click attempt
# clicked: 762 times.
# Click attempt
# clicked: 763 times.
# Click attempt
# clicked: 764 times.
# Click attempt
# clicked: 765 times.
# Click attempt
# clicked: 766 times.
# Click attempt
# clicked: 767 times.
# Click attempt
# clicked: 768 times.
# Click attempt
# clicked: 769 times.
# Click attempt
# clicked: 770 times.
# Click attempt
# clicked: 771 times.
# Click attempt
# clicked: 772 times.
# Click attempt
# clicked: 773 times.
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# clicked: 6 times.
# Click attempt
# clicked: 7 times.
# Click attempt
# clicked: 8 times.
# Click attempt
# clicked: 9 times.
# Click attempt
# clicked: 10 times.
# Click attempt
# clicked: 11 times.
# Click attempt
# clicked: 12 times.
# Click attempt
# clicked: 13 times.
# Click attempt
# clicked: 14 times.
# Click attempt
# clicked: 15 times.
# Click attempt
# clicked: 16 times.
# Click attempt
# clicked: 17 times.
# Click attempt
# clicked: 18 times.
# Click attempt
# clicked: 19 times.
# Click attempt
# clicked: 20 times.
# Click attempt
# clicked: 21 times.
# Click attempt
# clicked: 22 times.
# Click attempt
# clicked: 23 times.
# Click attempt
# clicked: 24 times.
# Click attempt
# clicked: 25 times.
# Click attempt
# clicked: 26 times.
# Click attempt
# clicked: 27 times.
# Click attempt
# clicked: 28 times.
# Click attempt
# clicked: 29 times.
# Click attempt
# clicked: 30 times.
# Click attempt
# clicked: 31 times.
# Click attempt
# clicked: 32 times.
# Click attempt
# clicked: 33 times.
# Click attempt
# clicked: 34 times.
# Click attempt
# clicked: 35 times.
# Click attempt
# clicked: 36 times.
# Click attempt
# clicked: 37 times.
# Click attempt
# clicked: 38 times.
# Click attempt
# clicked: 39 times.
# Click attempt
# clicked: 40 times.
# Click attempt
# clicked: 41 times.
# Click attempt
# clicked: 42 times.
# Click attempt
# clicked: 43 times.
# Click attempt
# clicked: 44 times.
# Click attempt
# clicked: 45 times.
# Click attempt
# clicked: 46 times.
# Click attempt
# clicked: 47 times.
# Click attempt
# clicked: 48 times.
# Click attempt
# clicked: 49 times.
# Click attempt
# clicked: 50 times.
# Click attempt
# clicked: 51 times.
# Click attempt
# clicked: 52 times.
# Click attempt
# clicked: 53 times.
# Click attempt
# clicked: 54 times.
# Click attempt
# clicked: 55 times.
# Click attempt
# clicked: 56 times.
# Click attempt
# clicked: 57 times.
# Click attempt
# clicked: 58 times.
# Click attempt
# clicked: 59 times.
# Click attempt
# clicked: 60 times.
# Click attempt
# clicked: 61 times.
# Click attempt
# clicked: 62 times.
# Click attempt
# clicked: 63 times.
# Click attempt
# clicked: 64 times.
# Click attempt
# clicked: 65 times.
# Click attempt
# clicked: 66 times.
# Click attempt
# clicked: 67 times.
# Click attempt
# clicked: 68 times.
# Click attempt
# clicked: 69 times.
# Click attempt
# clicked: 70 times.
# Click attempt
# clicked: 71 times.
# Click attempt
# clicked: 72 times.
# Click attempt
# clicked: 73 times.
# Click attempt
# clicked: 74 times.
# Click attempt
# clicked: 75 times.
# Click attempt
# clicked: 76 times.
# Click attempt
# clicked: 77 times.
# Click attempt
# clicked: 78 times.
# Click attempt
# clicked: 79 times.
# Click attempt
# clicked: 80 times.
# Click attempt
# clicked: 81 times.
# Click attempt
# clicked: 82 times.
# Click attempt
# clicked: 83 times.
# Click attempt
# clicked: 84 times.
# Click attempt
# clicked: 85 times.
# Click attempt
# clicked: 86 times.
# Click attempt
# clicked: 87 times.
# Click attempt
# clicked: 88 times.
# Click attempt
# clicked: 89 times.
# Click attempt
# clicked: 90 times.
# Click attempt
# clicked: 91 times.
# Click attempt
# clicked: 92 times.
# Click attempt
# clicked: 93 times.
# Click attempt
# clicked: 94 times.
# Click attempt
# clicked: 95 times.
# Click attempt
# clicked: 96 times.
# Click attempt
# clicked: 97 times.
# Click attempt
# clicked: 98 times.
# Click attempt
# clicked: 99 times.
# Click attempt
# clicked: 100 times.
# Click attempt
# clicked: 101 times.
# Click attempt
# clicked: 102 times.
# Click attempt
# clicked: 103 times.
# Click attempt
# clicked: 104 times.
# Click attempt
# clicked: 105 times.
# Click attempt
# clicked: 106 times.
# Click attempt
# clicked: 107 times.
# Click attempt
# clicked: 108 times.
# Click attempt
# clicked: 109 times.
# Click attempt
# clicked: 110 times.
# Click attempt
# clicked: 111 times.
# Click attempt
# clicked: 112 times.
# Click attempt
# clicked: 113 times.
# Click attempt
# clicked: 114 times.
# Click attempt
# clicked: 115 times.
# Click attempt
# clicked: 116 times.
# Click attempt
# clicked: 117 times.
# Click attempt
# clicked: 118 times.
# Click attempt
# clicked: 119 times.
# Click attempt
# clicked: 120 times.
# Click attempt
# clicked: 121 times.
# Click attempt
# clicked: 122 times.
# Click attempt
# clicked: 123 times.
# Click attempt
# clicked: 124 times.
# Click attempt
# clicked: 125 times.
# Click attempt
# clicked: 126 times.
# Click attempt
# clicked: 127 times.
# Click attempt
# clicked: 128 times.
# Click attempt
# clicked: 129 times.
# Click attempt
# clicked: 130 times.
# Click attempt
# clicked: 131 times.
# Click attempt
# clicked: 132 times.
# Click attempt
# clicked: 133 times.
# Click attempt
# clicked: 134 times.
# Click attempt
# clicked: 135 times.
# Click attempt
# clicked: 136 times.
# Click attempt
# clicked: 137 times.
# Click attempt
# clicked: 138 times.
# Click attempt
# clicked: 139 times.
# Click attempt
# clicked: 140 times.
# Click attempt
# clicked: 141 times.
# Click attempt
# clicked: 142 times.
# Click attempt
# clicked: 143 times.
# Click attempt
# clicked: 144 times.
# Click attempt
# clicked: 145 times.
# Click attempt
# clicked: 146 times.
# Click attempt
# clicked: 147 times.
# Click attempt
# clicked: 148 times.
# Click attempt
# clicked: 149 times.
# Click attempt
# clicked: 150 times.
# Click attempt
# clicked: 151 times.
# Click attempt
# clicked: 152 times.
# Click attempt
# clicked: 153 times.
# Click attempt
# clicked: 154 times.
# Click attempt
# clicked: 155 times.
# Click attempt
# clicked: 156 times.
# Click attempt
# clicked: 157 times.
# Click attempt
# clicked: 158 times.
# Click attempt
# clicked: 159 times.
# Click attempt
# clicked: 160 times.
# Click attempt
# clicked: 161 times.
# Click attempt
# clicked: 162 times.
# Click attempt
# clicked: 163 times.
# Click attempt
# clicked: 164 times.
# Click attempt
# clicked: 165 times.
# Click attempt
# clicked: 166 times.
# Click attempt
# clicked: 167 times.
# Click attempt
# clicked: 168 times.
# Click attempt
# clicked: 169 times.
# Click attempt
# clicked: 170 times.
# Click attempt
# clicked: 171 times.
# Click attempt
# clicked: 172 times.
# Click attempt
# clicked: 173 times.
# Click attempt
# clicked: 174 times.
# Click attempt
# clicked: 175 times.
# Click attempt
# clicked: 176 times.
# Click attempt
# clicked: 177 times.
# Click attempt
# clicked: 178 times.
# Click attempt
# clicked: 179 times.
# Click attempt
# clicked: 180 times.
# Click attempt
# clicked: 181 times.
# Click attempt
# clicked: 182 times.
# Click attempt
# clicked: 183 times.
# Click attempt
# clicked: 184 times.
# Click attempt
# clicked: 185 times.
# Click attempt
# clicked: 186 times.
# Click attempt
# clicked: 187 times.
# Click attempt
# clicked: 188 times.
# Click attempt
# clicked: 189 times.
# Click attempt
# clicked: 190 times.
# Click attempt
# clicked: 191 times.
# Click attempt
# clicked: 192 times.
# Click attempt
# clicked: 193 times.
# Click attempt
# clicked: 194 times.
# Click attempt
# clicked: 195 times.
# Click attempt
# clicked: 196 times.
# Click attempt
# clicked: 197 times.
# Click attempt
# clicked: 198 times.
# Click attempt
# clicked: 199 times.
# Click attempt
# clicked: 200 times.
# Click attempt
# clicked: 201 times.
# Click attempt
# clicked: 202 times.
# Click attempt
# clicked: 203 times.
# Click attempt
# clicked: 204 times.
# Click attempt
# clicked: 205 times.
# Click attempt
# clicked: 206 times.
# Click attempt
# clicked: 207 times.
# Click attempt
# clicked: 208 times.
# Click attempt
# clicked: 209 times.
# Click attempt
# clicked: 210 times.
# Click attempt
# clicked: 211 times.
# Click attempt
# clicked: 212 times.
# Click attempt
# clicked: 213 times.
# Click attempt
# clicked: 214 times.
# Click attempt
# clicked: 215 times.
# Click attempt
# clicked: 216 times.
# Click attempt
# clicked: 217 times.
# Click attempt
# clicked: 218 times.
# Click attempt
# clicked: 219 times.
# Click attempt
# clicked: 220 times.
# Click attempt
# clicked: 221 times.
# Click attempt
# clicked: 222 times.
# Click attempt
# clicked: 223 times.
# All done!
# True
# Click attempt
# clicked: 1 times.
# Click attempt
# clicked: 2 times.
# Click attempt
# clicked: 3 times.
# Click attempt
# clicked: 4 times.
# Click attempt
# clicked: 5 times.
# Click attempt
# clicked: 6 times.
# Click attempt
# clicked: 7 times.
# Click attempt
# clicked: 8 times.
# Click attempt
# clicked: 9 times.
# Click attempt
# clicked: 10 times.
# Click attempt
# clicked: 11 times.
# Click attempt
# clicked: 12 times.
# Click attempt
# clicked: 13 times.
# Click attempt
# clicked: 14 times.
# Click attempt
# clicked: 15 times.
# Click attempt
# clicked: 16 times.
# All done!

# %%
# End selenium session.        
driver.close()

# %%
df = pd.DataFrame(data_list)
len(data_list)
prov_scraped
# Out:
# ['ON', 'BC', 'MB', 'AB', 'NB', 'NL', 'NT', 'NS', 'NU', 'PE', 'QC', 'SK', 'YT']

# %%
len(data_list)
df
# Out:
#                                                job_title  \
# 0      assistant manager - food servicesVerifiedThis ...
# 1      shift manager - fast food restaurantVerifiedTh...
# 2      retail store supervisorVerifiedThis job was po...
# 3      diesel mechanicVerifiedThis job was posted dir...
# 4      assistant manager - food servicesVerifiedThis ...
# ...                                                  ...
# 59551                                            planner
# 59552                                   dental assistant
# 59553                electrical engineering technologist
# 59554                       construction project manager
# 59555                                            cashier
#
#                                 business                    location  \
# 0                             Royal Paan    Location   Brampton (ON)
# 1           CAR - JON FAMILY RESTAURANTS      Location   London (ON)
# 2      PRESCOTT SMOKESHOP & GROCERY INC.    Location   Prescott (ON)
# 3               Bullewadd Transport Ltd.     Location   Windsor (ON)
# 4                             Royal Paan      Location   Milton (ON)
# ...                                  ...                         ...
# 59551                          What Jobs  Location   Whitehorse (YT)
# 59552                          What Jobs  Location   Whitehorse (YT)
# 59553                          What Jobs  Location   Whitehorse (YT)
# 59554                          What Jobs        Location   Faro (YT)
# 59555                          What Jobs  Location   Whitehorse (YT)
#
#                                                   salary  \
# 0                                   Salary:$27.50 hourly
# 1                                   Salary:$19.20 hourly
# 2      Salary:$18.66 to $20.00 hourly (to be negotiated)
# 3                                   Salary:$30.50 hourly
# 4                                   Salary:$27.50 hourly
# ...                                                  ...
# 59551                               Salary not available
# 59552                               Salary not available
# 59553                               Salary not available
# 59554                               Salary not available
# 59555                               Salary not available
#
#                                                     link  \
# 0      /jobsearch/jobposting/39620155;jsessionid=52C7...
# 1      /jobsearch/jobposting/39620154;jsessionid=52C7...
# 2      /jobsearch/jobposting/39620150;jsessionid=52C7...
# 3      /jobsearch/jobposting/39620127;jsessionid=52C7...
# 4      /jobsearch/jobposting/39620129;jsessionid=52C7...
# ...                                                  ...
# 59551  /jobsearch/jobposting/39430853?source=searchre...
# 59552  /jobsearch/jobposting/39427100?source=searchre...
# 59553  /jobsearch/jobposting/39432269?source=searchre...
# 59554  /jobsearch/jobposting/39427939?source=searchre...
# 59555  /jobsearch/jobposting/39430841?source=searchre...
#
#                                 date
# 0      November 21, 2023\n\t\t\t\t\t
# 1      November 21, 2023\n\t\t\t\t\t
# 2      November 21, 2023\n\t\t\t\t\t
# 3      November 21, 2023\n\t\t\t\t\t
# 4      November 21, 2023\n\t\t\t\t\t
# ...                              ...
# 59551   October 24, 2023\n\t\t\t\t\t
# 59552   October 24, 2023\n\t\t\t\t\t
# 59553   October 24, 2023\n\t\t\t\t\t
# 59554   October 24, 2023\n\t\t\t\t\t
# 59555   October 24, 2023\n\t\t\t\t\t
#
# [59556 rows x 6 columns]

# %%
compresion_opts = dict(method='zip', archive_name=f'out-all.csv')

# make folder and output to it
os.makedirs('output', exist_ok=True)
df.to_csv(f'output/out-all.zip', compression=compresion_opts)
